# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# uniform distribution
nums = np.random.rand(1000) 
# nums = nums + 3 # shifts distribution

# generate desired min and max values-------
minval = 2
maxval = 17
nums = nums*(maxval-minval) + minval

plt.plot(nums,'ro') # values on y axis
plt.show()

plt.hist(nums) # values on x axis
plt.show()

# %%
# normal distribution
nums = np.random.randn(1000) # n in rand = normal

plt.plot(nums,'ro',alpha=.5) # values on y axis # alpha changes transparency
plt.show()

plt.hist(nums) # values on x axis
plt.show()

# %%
# experimental
nums = np.random.rand(1000)
numsn = np.random.randn(1000)
numsn = np.

plt.plot(nums)

# %%
# exercise.independent
# mean =15
# standard deviation = 4.3

nums = np.random.randn(1000) # n in rand = normal
nums = nums * 4.3 + 15


plt.plot(nums,'ro',alpha=.5) # values on y axis # alpha changes transparency
plt.show()


plt.hist(nums) # values on x axis
plt.show()

# %%
# exercise.instructed
desired_mean = 15
desired_std = 4.3

nums = np.random.randn(1000)
nums = nums - np.mean(nums)
nums = nums/np.std(nums)

nums = nums * desired_std + desired_mean  

plt.subplot(121) # row,col,subplot num
plt.plot(nums,'s')

plt.subplot(122)
plt.hist(nums)

plt.show()

print('This distribution has a mean of %s and a standard deviation \
# %s' %(np.mean(nums),np.std(nums)))
# Out:
# This distribution has a mean of 15.0 and a standard deviation 4.3

# %%
# experimental
# mean =15
# standard deviation = 4.3

nums = np.random.randn(1000) # n in rand = normal
nums = nums * 4.3 + 15

plt.subplot(131)
plt.plot(nums,'ro',alpha=.5) # values on y axis # alpha changes transparency


plt.subplot(132)
plt.hist(nums) # values on x axis
plt.show()
